# %% [markdown]
# # Ungraded Lab: First Autoencoder
#
# In this lab, you will build your first simple autoencoder. This will take in three-dimensional data, encodes it to two dimensions, and decodes it back to 3D.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Prepare and preview the dataset
#
# You will first create a synthetic dataset to act as input to the autoencoder. You can do that with the function below.

# %%
def generate_data(m):
  """plots m random points on a 3D plane"""
  angles = np.random.rand(m) * 3 * np.pi / 2 - 0.5
  data = np.empty((m, 3))
  data[:,0] = np.cos(angles) + np.sin(angles)/2 + 0.1 * np.random.rand(m)/2
  data[:,1] = np.sin(angles) * 0.7 + 0.1 * np.random.rand(m) / 2
  data[:,2] = data[:,0] * 0.1 + data[:,1] * 0.3 + 0.1 * np.random.rand(m)

  return data

# %%
# use the function above to generate data points
X_train = generate_data(100)
X_train = X_train - X_train.mean(axis=0, keepdims=0)

# preview the data
ax = plt.axes(projection="3d")
ax.scatter3D(X_train[:, 0], X_train[:, 1], X_train[:, 2], cmap="Reds")

# %% [markdown]
# ## Build the Model

# %% [markdown]
# Now you will build the simple encoder-decoder model. Notice the number of neurons in each Dense layer. The model will contract in the encoder then expand in the decoder.

# %%
encoder = keras.models.Sequential([keras.layers.Dense(2, input_shape=[3])])
decoder = keras.models.Sequential([keras.layers.Dense(3, input_shape=[2])])

autoencoder = keras.models.Sequential([encoder, decoder])

# %% [markdown]
# ## Compile the Model

# %% [markdown]
# You can then setup the model for training.

# %%
autoencoder.compile(loss="mse", optimizer=keras.optimizers.SGD(learning_rate=0.1))

# %% [markdown]
# ## Train the Model

# %% [markdown]
# You will configure the training to also use the input data as your target output. In our example, that will be `X_train`.

# %%
history = autoencoder.fit(X_train, X_train, epochs=200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 2s 5ms/step - loss: 1.1984
# Epoch 2/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3387
# Epoch 3/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1452
# Epoch 4/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0889
# Epoch 5/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0723
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0633
# Epoch 7/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0573
# Epoch 8/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0531
# Epoch 9/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0506
# Epoch 10/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0481
# Epoch 11/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0454
# Epoch 12/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0439
# Epoch 13/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0417
# Epoch 14/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0402
# Epoch 15/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0390
# Epoch 16/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0380
# Epoch 17/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0367
# Epoch 18/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0361
# Epoch 19/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0356
# Epoch 20/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0344
# Epoch 21/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0338
# Epoch 22/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0331
# Epoch 23/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0324
# Epoch 24/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0319
# Epoch 25/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0313
# Epoch 26/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0310
# Epoch 27/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0301
# Epoch 28/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0297
# Epoch 29/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0292
# Epoch 30/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0288
# Epoch 31/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0283
# Epoch 32/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0280
# Epoch 33/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0275
# Epoch 34/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0271
# Epoch 35/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0266
# Epoch 36/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0263
# Epoch 37/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0261
# Epoch 38/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0256
# Epoch 39/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0252
# Epoch 40/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0248
# Epoch 41/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0245
# Epoch 42/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0243
# Epoch 43/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0239
# Epoch 44/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0234
# Epoch 45/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0232
# Epoch 46/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0226
# Epoch 47/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0222
# Epoch 48/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0219
# Epoch 49/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0216
# Epoch 50/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0214
# Epoch 51/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0210
# Epoch 52/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0206
# Epoch 53/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0202
# Epoch 54/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0200
# Epoch 55/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0196
# Epoch 56/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0194
# Epoch 57/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0191
# Epoch 58/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0187
# Epoch 59/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0184
# Epoch 60/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0180
# Epoch 61/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0178
# Epoch 62/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0176
# Epoch 63/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0172
# Epoch 64/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0169
# Epoch 65/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0165
# Epoch 66/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0163
# Epoch 67/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0160
# Epoch 68/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0157
# Epoch 69/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0153
# Epoch 70/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0151
# Epoch 71/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0148
# Epoch 72/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0144
# Epoch 73/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0142
# Epoch 74/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0139
# Epoch 75/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0136
# Epoch 76/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0133
# Epoch 77/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0130
# Epoch 78/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0128
# Epoch 79/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0126
# Epoch 80/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 81/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0119
# Epoch 82/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0117
# Epoch 83/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0114
# Epoch 84/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0112
# Epoch 85/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0110
# Epoch 86/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0107
# Epoch 87/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0105
# Epoch 88/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0103
# Epoch 89/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0101
# Epoch 90/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0098
# Epoch 91/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0096
# Epoch 92/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0094
# Epoch 93/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0092
# Epoch 94/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0089
# Epoch 95/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0087
# Epoch 96/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0085
# Epoch 97/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0083
# Epoch 98/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0081
# Epoch 99/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0079
# Epoch 100/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0076
# Epoch 101/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 102/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0072
# Epoch 103/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0070
# Epoch 104/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 105/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 106/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 107/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0063
# Epoch 108/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0062
# Epoch 109/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0060
# Epoch 110/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0058
# Epoch 111/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0056
# Epoch 112/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0055
# Epoch 113/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0054
# Epoch 114/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0052
# Epoch 115/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0051
# Epoch 116/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0050
# Epoch 117/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 118/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0047
# Epoch 119/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 120/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 121/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 122/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 123/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 124/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0040
# Epoch 125/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0039
# Epoch 126/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0038
# Epoch 127/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 128/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0036
# Epoch 129/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0035
# Epoch 130/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 131/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 132/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 133/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0031
# Epoch 134/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0031
# Epoch 135/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 136/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 137/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0028
# Epoch 138/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 139/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 140/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 141/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0025
# Epoch 142/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 143/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 144/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 145/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 146/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 147/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 148/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 149/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 150/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 151/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 152/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 153/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 154/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 155/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 156/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 157/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 158/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 159/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 160/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 161/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 162/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 163/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 164/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 165/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 166/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 167/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 168/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 169/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 170/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 171/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 172/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 173/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 174/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 175/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 176/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 177/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 178/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.8689e-04
# Epoch 179/200
# 4/4 [==============================] - 0s 5ms/step - loss: 9.6113e-04
# Epoch 180/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.3872e-04
# Epoch 181/200
# 4/4 [==============================] - 0s 4ms/step - loss: 9.1461e-04
# Epoch 182/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.9604e-04
# Epoch 183/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.7548e-04
# Epoch 184/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.6006e-04
# Epoch 185/200
# 4/4 [==============================] - 0s 5ms/step - loss: 8.4173e-04
# Epoch 186/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.2908e-04
# Epoch 187/200
# 4/4 [==============================] - 0s 4ms/step - loss: 8.1284e-04
# Epoch 188/200
# 4/4 [==============================] - 0s 5ms/step - loss: 7.8785e-04
# Epoch 189/200
# 4/4 [==============================] - 0s 5ms/step - loss: 7.6869e-04
# Epoch 190/200
# 4/4 [==============================] - 0s 4ms/step - loss: 7.5585e-04
# Epoch 191/200
# 4/4 [==============================] - 0s 4ms/step - loss: 7.3864e-04
# Epoch 192/200
# 4/4 [==============================] - 0s 4ms/step - loss: 7.3126e-04
# Epoch 193/200
# 4/4 [==============================] - 0s 6ms/step - loss: 7.1577e-04
# Epoch 194/200
# 4/4 [==============================] - 0s 4ms/step - loss: 6.9972e-04
# Epoch 195/200
# 4/4 [==============================] - 0s 4ms/step - loss: 6.8845e-04
# Epoch 196/200
# 4/4 [==============================] - 0s 5ms/step - loss: 6.7508e-04
# Epoch 197/200
# 4/4 [==============================] - 0s 4ms/step - loss: 6.6169e-04
# Epoch 198/200
# 4/4 [==============================] - 0s 5ms/step - loss: 6.5355e-04
# Epoch 199/200
# 4/4 [==============================] - 0s 4ms/step - loss: 6.4039e-04
# Epoch 200/200
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2771e-04

# %% [markdown]
# ## Plot the encoder output

# %% [markdown]
# As mentioned, you can use the encoder to compress the input to two dimensions.

# %%
# encode the data
codings = encoder.predict(X_train)

# see a sample input-encoder output pair
print(f'input point: {X_train[0]}')
print(f'encoded point: {codings[0]}')
# Out:
# input point: [0.9613872  0.26282647 0.19117951]
# encoded point: [0.12462617 0.99262464]

# %%
# plot all encoder outputs
fig = plt.figure(figsize=(4,3))
plt.plot(codings[:, 0], codings[:, 1], 'b.')
plt.xlabel("$z_1$", fontsize=18)
plt.ylabel("$z_2$", fontsize=18, rotation=0)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Plot the Decoder output

# %% [markdown]
# The decoder then tries to reconstruct the original input. See the outputs below. You will see that although not perfect, it still follows the general shape of the original input.

# %%
# decode the encoder output
decodings = decoder.predict(codings)

# see a sample output for a single point
print(f'input point: {X_train[0]}')
print(f'encoded point: {codings[0]}')
print(f'decoded point: {decodings[0]}')
# Out:
# input point: [0.9613872  0.26282647 0.19117951]
# encoded point: [0.12462617 0.99262464]
# decoded point: [0.9677573 0.2690749 0.1753378]

# %%
# plot the decoder output
ax = plt.axes(projection='3d')
ax.scatter3D(decodings[:, 0], decodings[:, 1], decodings[:, 2], c=decodings[:, 0], cmap="Reds")

# %% [markdown]
# That's it for this simple demonstration of the autoencoder!
